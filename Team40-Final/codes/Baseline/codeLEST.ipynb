# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/abhishek/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET
from nltk.corpus import wordnet as wn
# puncutaiton 
import string


data = pd.read_csv('../NN/SemCor/semcor_copy.csv')
# data2 = pd.read_csv('semcor4.csv')
# data = pd.concat([data1, data2], ignore_index=True)

# %%
def simple_lesk(cotext_sentence,amb_word):
    max_overlap = 0
    lesk_sense = None
    context_words = nltk.word_tokenize(cotext_sentence)
    context_words = set(context_words)
    # print(wn.synsets(amb_word))
    for sense in wn.synsets(amb_word):
        print(sense)
        signature = set()
        sene_definitions = nltk.word_tokenize(sense.definition())
        signature = signature.union(set(sene_definitions))
        signature = signature.union(set(sense.lemma_names()))
        for example in sense.examples():
            signature = signature.union(set(example.split()))
        overlap = len(context_words.intersection(signature))
        if overlap > max_overlap:
            lesk_sense = sense
            max_overlap = overlap

    return lesk_sense

# %%
def conversion(sense):
    trg = None 
    long_lemma = wn.lemma_from_key(sense)
    long_synset = long_lemma.synset()
    trg = long_synset.name()
    return trg

# %%
def accuracy(algorithm, data):
    correct = 0
    for i in range(len(data)):
        context = data['context'][i]
        word = data['sense_full'][i]
        word = word.split('.')[0]
        pred_sense = algorithm(context, word)
        print(pred_sense)
        if pred_sense is None:
            continue

        if data['sense_full'][i] == pred_sense.name():
            correct += 1

    return correct/len(data)*100

# %% [markdown]
# #### Accuracy of Simple Lesk Algorithm

# %%
print(accuracy(simple_lesk, data), "%")
# Out:
# Synset('person.n.01')
# Synset('person.n.02')
# Synset('person.n.03')
# Synset('person.n.01')
# Synset('year.n.01')
# Synset('year.n.02')
# Synset('year.n.03')
# Synset('class.n.06')
# Synset('year.n.03')
# Synset('now.n.01')
# Synset('now.r.01')
# Synset('nowadays.r.01')
# Synset('now.r.03')
# Synset('now.r.04')
# Synset('immediately.r.01')
# Synset('now.r.06')
# Synset('now.r.07')
# Synset('immediately.r.01')
# Synset('commuter.n.01')
# Synset('commuter.n.02')
# Synset('commuter.n.01')
# Synset('railway.n.01')
# Synset('railroad_track.n.01')
# Synset('railway.n.01')
# Synset('serve.n.01')
# Synset('serve.v.01')
# Synset('serve.v.02')
# Synset('serve.v.03')
# Synset('service.v.01')
# Synset('serve.v.05')
# Synset('serve.v.06')
# Synset('serve.v.07')
# Synset('serve.v.08')
# Synset('serve.v.09')
# Synset('serve.v.10')
# Synset('serve.v.11')
# Synset('suffice.v.01')
# Synset('serve.v.13')
# Synset('serve.v.14')
# Synset('serve.v.15')
# Synset('serve.v.10')
# Synset('large.n.01')
# Synset('large.a.01')
# Synset('large.s.02')
# Synset('bombastic.s.01')
# Synset('big.s.11')
# Synset('big.s.05')
# Synset('large.s.06')
# Synset('big.s.13')
# Synset('large.r.01')
# Synset('large.r.02')
# Synset('boastfully.r.01')
# Synset('large.a.01')
# Synset('metropolitan.n.01')
# Synset('metropolitan.n.02')
# Synset('metropolitan.a.01')
# Synset('metropolitan.n.01')
# Synset('area.n.01')
# Synset('area.n.02')
# Synset('area.n.03')
# Synset('sphere.n.01')
# Synset('area.n.05')
# Synset('area.n.06')
# Synset('area.n.01')
# Synset('determine.v.01')
# Synset('determine.v.02')
# Synset('determine.v.03')
# Synset('specify.v.02')
# Synset('decide.v.01')
# Synset('determine.v.06')
# Synset('settle.v.03')
# Synset('determine.v.08')
# Synset('determine.v.01')
# Synset('increasingly.r.01')
# Synset('increasingly.r.01')
# Synset('difficult.a.01')
# Synset('unmanageable.a.02')
# Synset('difficult.a.01')
# Synset('supply.n.01')
# Synset('supply.n.02')
# Synset('provision.n.02')
# Synset('supply.v.01')
# Synset('issue.v.02')
# Synset('provide.v.02')
# Synset('add.v.02')
# Synset('supply.v.01')
# Synset('kind.n.01')
# Synset('kind.a.01')
# Synset('kind.s.02')
# Synset('kind.s.03')
# Synset('kind.s.03')
# Synset('service.n.01')
# Synset('service.n.02')
# Synset('service.n.03')
# Synset('service.n.04')
# Synset('service.n.05')
# Synset('military_service.n.01')
# Synset('service.n.07')
# Synset('avail.n.01')
# Synset('service.n.09')
# Synset('servicing.n.01')
# Synset('service.n.11')
# Synset('serve.n.01')
# Synset('service.n.13')
# Synset('overhaul.n.01')
# Synset('service.n.15')
# Synset('service.v.01')
# Synset('service.v.02')
# Synset('serve.v.14')
# Synset('service.v.01')
# Synset('population.n.01')
# Synset('population.n.02')
# Synset('population.n.03')
# Synset('population.n.04')
# Synset('population.n.05')
# Synset('population.n.01')
# Synset('desire.n.01')
# Synset('desire.n.02')
# Synset('desire.n.03')
# Synset('desire.v.01')
# Synset('hope.v.01')
# Synset('desire.v.03')
# Synset('desire.n.02')
# Synset('entitle.v.01')
# Synset('entitle.v.02')
# Synset('ennoble.v.02')
# Synset('entitled.s.01')
# Synset('entitle.v.01')
# Synset('receive.v.01')
# Synset('receive.v.02')
# Synset('pick_up.v.09')
# Synset('experience.v.03')
# Synset('receive.v.05')
# Synset('receive.v.06')
# Synset('welcome.v.02')
# Synset('receive.v.08')
# Synset('meet.v.11')
# Synset('receive.v.10')
# Synset('get.v.25')
# Synset('receive.v.12')
# Synset('receive.v.13')
# Synset('receive.v.01')
# Synset('cause.n.01')
# Synset('cause.n.02')
# Synset('campaign.n.02')
# Synset('causal_agent.n.01')
# Synset('lawsuit.n.01')
# Synset('cause.v.01')
# Synset('induce.v.02')
# Synset('cause.n.01')
# Synset('decline.n.01')
# Synset('decline.n.02')
# Synset('decay.n.02')
# Synset('descent.n.05')
# Synset('worsen.v.01')
# Synset('refuse.v.02')
# Synset('refuse.v.01')
# Synset('decline.v.04')
# Synset('decline.v.05')
# Synset('decline.v.06')
# Synset('decline.v.07')
# Synset('refuse.v.02')
# Synset('commuter.n.01')
# Synset('commuter.n.02')
# Synset('commuter.n.01')
# Synset('railway.n.01')
# Synset('railroad_track.n.01')
# Synset('railway.n.01')
# Synset('exist.v.01')
# Synset('exist.v.02')
# Synset('exist.v.02')
# Synset('many.a.01')
# Synset('many.a.01')
# Synset('complex.n.01')
# Synset('complex.n.02')
# Synset('complex.n.03')
# Synset('building_complex.n.01')
# Synset('complex.a.01')
# Synset('complex.n.02')
# Synset('high.n.01')
# Synset('high.n.02')
# Synset('high.n.03')
# Synset('high.n.04')
# Synset('high.n.05')
# Synset('senior_high_school.n.01')
# Synset('high_gear.n.01')
# Synset('high.a.01')
# Synset('high.a.02')
# Synset('eminent.s.01')
# Synset('high.a.04')
# Synset('high.s.05')
# Synset('gamey.s.02')
# Synset('high.s.07')
# Synset('high.r.01')
# Synset('high.r.02')
# Synset('high.r.03')
# Synset('high.r.04')
# Synset('high.n.02')
# Synset('tax.n.01')
# Synset('tax.v.01')
# Synset('tax.v.02')
# Synset('tax.v.03')
# Synset('tax.v.04')
# Synset('tax.v.03')
# Synset('losings.n.01')
# Synset('lose.v.01')
# Synset('lose.v.02')
# Synset('lose.v.03')
# Synset('misplace.v.01')
# Synset('lose.v.05')
# Synset('lose.v.06')
# Synset('lose.v.07')
# Synset('lose.v.08')
# Synset('fall_back.v.04')
# Synset('miss.v.01')
# Synset('suffer.v.11')
# Synset('lose.v.02')
# Synset('gross.n.01')
# Synset('gross.n.02')
# Synset('gross.v.01')
# Synset('gross.a.01')
# Synset('gross.s.02')
# Synset('gross.s.03')
# Synset('megascopic.s.01')
# Synset('arrant.s.01')
# Synset('crude.s.02')
# Synset('crying.s.02')
# Synset('megascopic.s.01')
# Synset('government.n.01')
# Synset('government.n.02')
# Synset('government.n.03')
# Synset('politics.n.02')
# Synset('government.n.01')
# Synset('subsidize.v.01')
# Synset('subsidize.v.02')
# Synset('subsidized.s.01')
# Synset('subsidize.v.02')
# Synset('highway.n.01')
# Synset('highway.n.01')
# Synset('carrier.n.01')
# Synset('carrier.n.02')
# Synset('aircraft_carrier.n.01')
# Synset('carrier.n.04')
# Synset('carrier.n.05')
# Synset('carrier_wave.n.01')
# Synset('mailman.n.01')
# Synset('carrier.n.08')
# Synset('carrier.n.09')
# Synset('carrier.n.10')
# Synset('carrier.n.11')
# Synset('carrier.n.02')
# Synset('mention.n.01')
# Synset('citation.n.03')
# Synset('mention.n.03')
# Synset('mention.v.01')
# Synset('note.v.01')
# Synset('mention.v.03')
# Synset('mention.n.01')
# Synset('two.n.01')
# Synset('deuce.n.04')
# Synset('two.s.01')
# Synset('deuce.n.04')
# Synset('solution.n.01')
# Synset('solution.n.02')
# Synset('solution.n.03')
# Synset('solution.n.04')
# Synset('solution.n.05')
# Synset('solution.n.01')
# Synset('problem.n.01')
# Synset('problem.n.02')
# Synset('trouble.n.01')
# Synset('problem.n.01')
# Synset('commuter.n.01')
# Synset('commuter.n.02')
# Synset('commuter.n.01')
# Synset('line.n.01')
# Synset('line.n.02')
# Synset('line.n.03')
# Synset('line.n.04')
# Synset('line.n.05')
# Synset('line.n.06')
# Synset('line.n.07')
# Synset('argumentation.n.02')
# Synset('cable.n.02')
# Synset('course.n.02')
# Synset('line.n.11')
# Synset('wrinkle.n.01')
# Synset('pipeline.n.02')
# Synset('line.n.14')
# Synset('telephone_line.n.02')
# Synset('line.n.16')
# Synset('lineage.n.01')
# Synset('line.n.18')
# Synset('occupation.n.01')
# Synset('line.n.20')
# Synset('channel.n.05')
# Synset('line.n.22')
# Synset('line.n.23')
# Synset('agate_line.n.01')
# Synset('credit_line.n.01')
# Synset('tune.n.01')
# Synset('line.n.27')
# Synset('note.n.02')
# Synset('line.n.29')
# Synset('production_line.n.01')
# Synset('line.v.01')
# Synset('line.v.02')
# Synset('trace.v.02')
# Synset('line.v.04')
# Synset('line.v.05')
# Synset('line.v.06')
# Synset('line.n.05')
# Synset('equally.r.01')
# Synset('evenly.r.01')
# Synset('equally.r.01')
# Synset('change.v.03')
# Synset('deviate.v.02')
# Synset('vary.v.03')
# Synset('vary.v.04')
# Synset('change.v.03')
# Synset('scope.n.01')
# Synset('range.n.02')
# Synset('range.n.03')
# Synset('range.n.04')
# Synset('range.n.05')
# Synset('range.n.06')
# Synset('image.n.07')
# Synset('compass.n.03')
# Synset('stove.n.01')
# Synset('range.v.01')
# Synset('roll.v.12')
# Synset('range.v.03')
# Synset('range.v.04')
# Synset('range.v.05')
# Synset('crop.v.05')
# Synset('range.v.07')
# Synset('rate.v.01')
# Synset('scope.n.01')
# Synset('all_the_way.r.01')
# Synset('clear.r.01')
# Synset('all_the_way.r.03')
# Synset('all_the_way.r.01')
# Synset('government.n.01')
# Synset('government.n.02')
# Synset('government.n.03')
# Synset('politics.n.02')
# Synset('government.n.01')
# Synset('possession.n.01')
# Synset('possession.n.02')
# Synset('possession.n.03')
# Synset('monomania.n.01')
# Synset('possession.n.05')
# Synset('self-control.n.02')
# Synset('possession.n.07')
# Synset('possession.n.01')
# Synset('complete.v.01')
# Synset('complete.v.02')
# Synset('dispatch.v.02')
# Synset('complete.v.04')
# Synset('complete.v.05')
# Synset('complete.a.01')
# Synset('complete.s.02')
# Synset('accomplished.s.01')
# Synset('arrant.s.01')
# Synset('complete.s.05')
# Synset('complete.s.05')
# Synset('discontinuance.n.01')
# Synset('discontinuance.n.01')
# Synset('important.a.01')
# Synset('significant.a.01')
# Synset('crucial.a.01')
# Synset('authoritative.s.01')
# Synset('important.s.05')
# Synset('crucial.a.01')
# Synset('service.n.01')
# Synset('service.n.02')
# Synset('service.n.03')
# Synset('service.n.04')
# Synset('service.n.05')
# Synset('military_service.n.01')
# Synset('service.n.07')
# Synset('avail.n.01')
# Synset('service.n.09')
# Synset('servicing.n.01')
# Synset('service.n.11')
# Synset('serve.n.01')
# Synset('service.n.13')
# Synset('overhaul.n.01')
# Synset('service.n.15')
# Synset('service.v.01')
# Synset('service.v.02')
# Synset('serve.v.14')
# Synset('service.n.15')
# Synset('number.n.01')
# Synset('number.n.02')
# Synset('act.n.04')
# Synset('phone_number.n.01')
# Synset('numeral.n.01')
# Synset('issue.n.02')
# Synset('number.n.07')
# Synset('number.n.08')
# Synset('number.n.09')
# Synset('number.n.10')
# Synset('number.n.11')
# Synset('total.v.01')
# Synset('number.v.02')
# Synset('number.v.03')
# Synset('count.v.05')
# Synset('count.v.01')
# Synset('number.v.06')
# Synset('number.n.01')
# Synset('healthy.a.01')
# Synset('healthy.s.02')
# Synset('healthy.s.03')
# Synset('healthy.s.04')
# Synset('goodly.s.01')
# Synset('healthy.s.04')
# Synset('plan.n.01')
# Synset('design.n.02')
# Synset('plan.n.03')
# Synset('plan.v.01')
# Synset('plan.v.02')
# Synset('plan.v.03')
# Synset('design.v.04')
# Synset('plan.n.01')
# Synset('undertaking.n.01')
# Synset('project.n.02')
# Synset('project.v.01')
# Synset('stick_out.v.01')
# Synset('project.v.03')
# Synset('project.v.04')
# Synset('project.v.05')
# Synset('project.v.06')
# Synset('plan.v.03')
# Synset('project.v.08')
# Synset('visualize.v.01')
# Synset('project.v.10')
# Synset('project.v.11')
# Synset('project.v.12')
# Synset('project.v.08')
# Synset('implement.n.01')
# Synset('implement.v.01')
# Synset('enforce.v.01')
# Synset('follow_through.v.02')
# Synset('follow_through.v.02')
# Synset('alternatively.r.01')
# Synset('alternatively.r.01')
# Synset('stand_by.v.01')
# Synset('stand_by.v.02')
# Synset('stand_by.v.03')
# Synset('stand_by.v.03')
# Synset('idly.r.01')
# Synset('idly.r.01')
# Synset('watch.n.01')
# Synset('watch.n.02')
# Synset('watch.n.03')
# Synset('watch.n.04')
# Synset('lookout.n.01')
# Synset('vigil.n.02')
# Synset('watch.v.01')
# Synset('watch.v.02')
# Synset('watch.v.03')
# Synset('watch.v.04')
# Synset('watch.v.05')
# Synset('watch.v.06')
# Synset('determine.v.08')
# Synset('vigil.n.02')
# Synset('commuter.n.01')
# Synset('commuter.n.02')
# Synset('commuter.n.02')
# Synset('railway.n.01')
# Synset('railroad_track.n.01')
# Synset('railway.n.01')
# Synset('service.n.01')
# Synset('service.n.02')
# Synset('service.n.03')
# Synset('service.n.04')
# Synset('service.n.05')
# Synset('military_service.n.01')
# Synset('service.n.07')
# Synset('avail.n.01')
# Synset('service.n.09')
# Synset('servicing.n.01')
# Synset('service.n.11')
# Synset('serve.n.01')
# Synset('service.n.13')
# Synset('overhaul.n.01')
# Synset('service.n.15')
# Synset('service.v.01')
# Synset('service.v.02')
# Synset('serve.v.14')
# Synset('service.v.01')
# Synset('worsen.v.01')
# Synset('worsen.v.02')
# Synset('worsen.v.01')
# Synset('fail.v.01')
# Synset('fail.v.02')
# Synset('fail.v.03')
# Synset('fail.v.04')
# Synset('fail.v.05')
# Synset('fail.v.06')
# Synset('fail.v.07')
# Synset('fail.v.08')
# Synset('fail.v.09')
# Synset('fail.v.10')
# Synset('fail.v.11')
# Synset('fail.v.08')
# Synset('volunteer.n.01')
# Synset('volunteer.n.02')
# Synset('tennessean.n.01')
# Synset('volunteer.v.01')
# Synset('volunteer.v.02')
# Synset('volunteer.v.03')
# Synset('unpaid.s.02')
# Synset('volunteer.v.02')
# Synset('hand.n.01')
# Synset('hired_hand.n.01')
# Synset('handwriting.n.01')
# Synset('hand.n.04')
# Synset('hand.n.05')
# Synset('hand.n.06')
# Synset('hand.n.07')
# Synset('hand.n.08')
# Synset('hand.n.09')
# Synset('hand.n.10')
# Synset('bridge_player.n.01')
# Synset('hand.n.12')
# Synset('hand.n.13')
# Synset('hand.n.14')
# Synset('pass.v.05')
# Synset('hand.v.02')
# Synset('hand.n.13')
# Synset('number.n.01')
# Synset('number.n.02')
# Synset('act.n.04')
# Synset('phone_number.n.01')
# Synset('numeral.n.01')
# Synset('issue.n.02')
# Synset('number.n.07')
# Synset('number.n.08')
# Synset('number.n.09')
# Synset('number.n.10')
# Synset('number.n.11')
# Synset('total.v.01')
# Synset('number.v.02')
# Synset('number.v.03')
# Synset('count.v.05')
# Synset('count.v.01')
# Synset('number.v.06')
# Synset('number.n.02')
# Synset('people.n.01')
# Synset('citizenry.n.01')
# Synset('people.n.03')
# Synset('multitude.n.03')
# Synset('people.v.01')
# Synset('people.v.02')
# Synset('people.n.01')
# Synset('flow.n.01')
# Synset('flow.n.02')
# Synset('flow.n.03')
# Synset('flow.n.04')
# Synset('stream.n.04')
# Synset('stream.n.02')
# Synset('menstruation.n.01')
# Synset('flow.v.01')
# Synset('run.v.06')
# Synset('flow.v.03')
# Synset('flow.v.04')
# Synset('hang.v.05')
# Synset('flow.v.06')
# Synset('menstruate.v.01')
# Synset('stream.n.04')
# Synset('metropolitan.n.01')
# Synset('metropolitan.n.02')
# Synset('metropolitan.a.01')
# Synset('metropolitan.n.01')
# Synset('sphere.n.01')
# Synset('sphere.n.02')
# Synset('sphere.n.03')
# Synset('sector.n.03')
# Synset('sphere.n.05')
# Synset('sphere.n.06')
# Synset('celestial_sphere.n.01')
# Synset('sphere.n.06')
# Synset('addition.n.03')
# Synset('increase.n.02')
# Synset('increase.n.03')
# Synset('increase.n.04')
# Synset('increase.n.05')
# Synset('increase.v.01')
# Synset('increase.v.02')
# Synset('addition.n.03')
# Synset('enormously.r.01')
# None
# Synset('world_war_ii.n.01')
# Synset('world_war_ii.n.01')
# Synset('railing.n.01')
# Synset('rail.n.02')
# Synset('track.n.09')
# Synset('rail.n.04')
# Synset('rail.n.05')
# Synset('rail.v.01')
# Synset('rail.v.02')
# Synset('rail.v.03')
# Synset('rail.v.04')
# Synset('rail.v.05')
# Synset('train.v.10')
# Synset('rail.v.07')
# Synset('rail.v.08')
# Synset('vilify.v.01')
# Synset('fulminate.v.01')
# Synset('rail.v.02')
# Synset('commutation.n.01')
# Synset('commutation.n.02')
# Synset('commutation.n.03')
# Synset('substitution.n.02')
# Synset('substitution.n.02')
# Synset('drop.n.01')
# Synset('drop.n.02')
# Synset('drop.n.03')
# Synset('cliff.n.01')
# Synset('drop.n.05')
# Synset('drop.n.06')
# Synset('drop_curtain.n.01')
# Synset('drop.n.08')
# Synset('drop.n.09')
# Synset('drop.v.01')
# Synset('drop.v.02')
# Synset('drop.v.03')
# Synset('sink.v.01')
# Synset('drop.v.05')
# Synset('drop.v.06')
# Synset('drop.v.07')
# Synset('drop.v.08')
# Synset('fell.v.01')
# Synset('drop.v.10')
# Synset('spend.v.02')
# Synset('flatten.v.03')
# Synset('dangle.v.01')
# Synset('dismiss.v.03')
# Synset('dribble.v.02')
# Synset('shed.v.01')
# Synset('drop.v.17')
# Synset('drop.v.18')
# Synset('neglect.v.01')
# Synset('drop.v.20')
# Synset('drop.v.21')
# Synset('devolve.v.03')
# Synset('drop.v.23')
# Synset('drop.n.02')
# Synset('million.n.01')
# Synset('million.n.02')
# Synset('million.s.01')
# Synset('million.n.01')
# Synset('nowhere.n.01')
# Synset('nowhere.r.01')
# Synset('nowhere.n.01')
# Synset('decline.n.01')
# Synset('decline.n.02')
# Synset('decay.n.02')
# Synset('descent.n.05')
# Synset('worsen.v.01')
# Synset('refuse.v.02')
# Synset('refuse.v.01')
# Synset('decline.v.04')
# Synset('decline.v.05')
# Synset('decline.v.06')
# Synset('decline.v.07')
# Synset('worsen.v.01')
# Synset('exist.v.01')
# Synset('exist.v.02')
# Synset('exist.v.02')
# Synset('more.n.01')
# Synset('more.a.01')
# Synset('more.a.02')
# Synset('more.r.01')
# Synset('more.r.02')
# Synset('more.n.01')
# Synset('painfully.r.01')
# Synset('painfully.r.02')
# None
# Synset('apparent.s.01')
# Synset('apparent.s.02')
# Synset('apparent.s.01')
# Synset('new_york.n.01')
# Synset('new_york.n.02')
# Synset('new_york.n.03')
# Synset('new_york.n.01')
# Synset('area.n.01')
# Synset('area.n.02')
# Synset('area.n.03')
# Synset('sphere.n.01')
# Synset('area.n.05')
# Synset('area.n.06')
# Synset('area.n.03')
# Synset('here.n.01')
# Synset('hera.n.01')
# Synset('here.s.01')
# Synset('here.r.01')
# Synset('here.r.02')
# Synset('here.r.03')
# Synset('here.r.04')
# Synset('hera.n.01')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.01')
# Synset('state.n.01')
# Synset('state.n.02')
# Synset('state.n.03')
# Synset('state.n.04')
# Synset('state_of_matter.n.01')
# Synset('state.n.06')
# Synset('country.n.02')
# Synset('department_of_state.n.01')
# Synset('state.v.01')
# Synset('submit.v.02')
# Synset('express.v.04')
# Synset('state.n.02')
# Synset('most.a.01')
# Synset('most.a.02')
# Synset('most.r.01')
# Synset('most.r.02')
# Synset('about.r.07')
# Synset('most.a.02')
# Synset('important.a.01')
# Synset('significant.a.01')
# Synset('crucial.a.01')
# Synset('authoritative.s.01')
# Synset('important.s.05')
# Synset('crucial.a.01')
# Synset('carrier.n.01')
# Synset('carrier.n.02')
# Synset('aircraft_carrier.n.01')
# Synset('carrier.n.04')
# Synset('carrier.n.05')
# Synset('carrier_wave.n.01')
# Synset('mailman.n.01')
# Synset('carrier.n.08')
# Synset('carrier.n.09')
# Synset('carrier.n.10')
# Synset('carrier.n.11')
# Synset('carrier.n.04')
# Synset('wholly.r.01')
# Synset('entirely.r.02')
# Synset('wholly.r.01')
# Synset('lose.v.01')
# Synset('lose.v.02')
# Synset('lose.v.03')
# Synset('misplace.v.01')
# Synset('lose.v.05')
# Synset('lose.v.06')
# Synset('lose.v.07')
# Synset('lose.v.08')
# Synset('fall_back.v.04')
# Synset('miss.v.01')
# Synset('suffer.v.11')
# Synset('lose.v.03')
# Synset('percentage.n.01')
# Synset('share.n.01')
# Synset('percentage.n.01')
# Synset('passenger.n.01')
# Synset('passenger.n.01')
# Synset('time.n.01')
# Synset('time.n.02')
# Synset('time.n.03')
# Synset('time.n.04')
# Synset('time.n.05')
# Synset('time.n.06')
# Synset('clock_time.n.01')
# Synset('fourth_dimension.n.01')
# Synset('meter.n.04')
# Synset('prison_term.n.01')
# Synset('clock.v.01')
# Synset('time.v.02')
# Synset('time.v.03')
# Synset('time.v.04')
# Synset('time.v.05')
# Synset('time.n.03')
# Synset('crisis.n.01')
# Synset('crisis.n.02')
# Synset('crisis.n.02')
# Synset('state.n.01')
# Synset('state.n.02')
# Synset('state.n.03')
# Synset('state.n.04')
# Synset('state_of_matter.n.01')
# Synset('state.n.06')
# Synset('country.n.02')
# Synset('department_of_state.n.01')
# Synset('state.v.01')
# Synset('submit.v.02')
# Synset('express.v.04')
# Synset('state.n.01')
# Synset('commuter.n.01')
# Synset('commuter.n.02')
# Synset('commuter.n.02')
# Synset('railway.n.01')
# Synset('railroad_track.n.01')
# Synset('railway.n.01')
# Synset('new.a.01')
# Synset('fresh.s.04')
# Synset('raw.s.12')
# Synset('new.s.04')
# Synset('new.s.05')
# Synset('new.a.06')
# Synset('newfangled.s.01')
# Synset('new.s.08')
# Synset('modern.s.05')
# Synset('new.s.10')
# Synset('new.s.11')
# Synset('newly.r.01')
# Synset('new.s.08')
# Synset('menace.n.01')
# Synset('menace.n.02')
# Synset('endanger.v.01')
# Synset('menace.v.02')
# Synset('menace.v.03')
# Synset('menace.n.01')
# Synset('continue.v.01')
# Synset('continue.v.02')
# Synset('continue.v.03')
# Synset('proceed.v.02')
# Synset('retain.v.02')
# Synset('continue.v.06')
# Synset('continue.v.07')
# Synset('stay.v.04')
# Synset('cover.v.03')
# Synset('continue.v.10')
# Synset('continued.a.01')
# Synset('retain.v.02')
# Synset('operation.n.01')
# Synset('operation.n.02')
# Synset('operation.n.03')
# Synset('operation.n.04')
# Synset('operation.n.05')
# Synset('operation.n.06')
# Synset('operation.n.07')
# Synset('operation.n.08')
# Synset('process.n.02')
# Synset('mathematical_process.n.01')
# Synset('operation.n.11')
# Synset('operation.n.04')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.03')
# Synset('look.v.02')
# Synset('appear.v.02')
# Synset('appear.v.03')
# Synset('appear.v.04')
# Synset('appear.v.05')
# Synset('appear.v.06')
# Synset('appear.v.07')
# Synset('appear.v.04')
# Synset('form.n.01')
# Synset('kind.n.01')
# Synset('form.n.03')
# Synset('shape.n.01')
# Synset('human_body.n.01')
# Synset('shape.n.02')
# Synset('form.n.07')
# Synset('form.n.08')
# Synset('form.n.09')
# Synset('form.n.10')
# Synset('form.n.11')
# Synset('phase.n.02')
# Synset('class.n.02')
# Synset('form.n.14')
# Synset('mannequin.n.02')
# Synset('form.n.16')
# Synset('form.v.01')
# Synset('form.v.02')
# Synset('form.v.03')
# Synset('shape.v.03')
# Synset('shape.v.02')
# Synset('imprint.v.01')
# Synset('form.v.07')
# Synset('form.n.01')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.01')
# Synset('proposal.n.01')
# Synset('marriage_proposal.n.01')
# Synset('proposal.n.03')
# Synset('proposal.n.03')
# Synset('control.n.01')
# Synset('control.n.02')
# Synset('control.n.03')
# Synset('control_condition.n.01')
# Synset('control.n.05')
# Synset('dominance.n.02')
# Synset('restraint.n.02')
# Synset('command.n.06')
# Synset('control.n.09')
# Synset('control.n.10')
# Synset('control.n.11')
# Synset('control.v.01')
# Synset('control.v.02')
# Synset('operate.v.03')
# Synset('manipulate.v.05')
# Synset('control.v.05')
# Synset('control.v.06')
# Synset('see.v.10')
# Synset('master.v.04')
# Synset('control.n.02')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.01')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.01')
# Synset('remark.n.01')
# Synset('comment.n.02')
# Synset('gossip.n.02')
# Synset('comment.v.01')
# Synset('comment.v.02')
# Synset('gloss.v.02')
# Synset('comment.n.02')
# Synset('control.n.01')
# Synset('control.n.02')
# Synset('control.n.03')
# Synset('control_condition.n.01')
# Synset('control.n.05')
# Synset('dominance.n.02')
# Synset('restraint.n.02')
# Synset('command.n.06')
# Synset('control.n.09')
# Synset('control.n.10')
# Synset('control.n.11')
# Synset('control.v.01')
# Synset('control.v.02')
# Synset('operate.v.03')
# Synset('manipulate.v.05')
# Synset('control.v.05')
# Synset('control.v.06')
# Synset('see.v.10')
# Synset('master.v.04')
# Synset('control.n.02')
# Synset('approve.v.01')
# Synset('approve.v.02')
# Synset('approve.v.01')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.03')
# Synset('output.n.02')
# Synset('return.n.06')
# Synset('yield.n.03')
# Synset('output.n.04')
# Synset('yield.v.01')
# Synset('give_way.v.03')
# Synset('render.v.04')
# Synset('concede.v.03')
# Synset('yield.v.05')
# Synset('move_over.v.01')
# Synset('give.v.09')
# Synset('concede.v.02')
# Synset('succumb.v.02')
# Synset('yield.v.10')
# Synset('give.v.33')
# Synset('yield.v.12')
# Synset('yield.v.13')
# Synset('return.n.06')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.01')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.01')
# Synset('sum.n.01')
# Synset('sum.n.02')
# Synset('sum.n.03')
# Synset('kernel.n.03')
# Synset('sum.n.05')
# Synset('union.n.08')
# Synset('summarize.v.02')
# Synset('total.v.02')
# Synset('kernel.n.03')
# Synset('point.n.01')
# Synset('point.n.02')
# Synset('point.n.03')
# Synset('detail.n.01')
# Synset('degree.n.02')
# Synset('point.n.06')
# Synset('point.n.07')
# Synset('point.n.08')
# Synset('point.n.09')
# Synset('point.n.10')
# Synset('point.n.11')
# Synset('item.n.01')
# Synset('point.n.13')
# Synset('point.n.14')
# Synset('point.n.15')
# Synset('compass_point.n.01')
# Synset('point.n.17')
# Synset('point.n.18')
# Synset('period.n.07')
# Synset('point.n.20')
# Synset('decimal_point.n.01')
# Synset('point.n.22')
# Synset('point.n.23')
# Synset('point.n.24')
# Synset('point.n.25')
# Synset('distributor_point.n.01')
# Synset('indicate.v.02')
# Synset('orient.v.01')
# Synset('charge.v.17')
# Synset('steer.v.01')
# Synset('bespeak.v.01')
# Synset('luff.v.01')
# Synset('point.v.07')
# Synset('point.v.08')
# Synset('point.v.09')
# Synset('point.v.10')
# Synset('target.v.01')
# Synset('point.v.12')
# Synset('sharpen.v.07')
# Synset('point.v.14')
# Synset('point.n.18')
# Synset('service.n.01')
# Synset('service.n.02')
# Synset('service.n.03')
# Synset('service.n.04')
# Synset('service.n.05')
# Synset('military_service.n.01')
# Synset('service.n.07')
# Synset('avail.n.01')
# Synset('service.n.09')
# Synset('servicing.n.01')
# Synset('service.n.11')
# Synset('serve.n.01')
# Synset('service.n.13')
# Synset('overhaul.n.01')
# Synset('service.n.15')
# Synset('service.v.01')
# Synset('service.v.02')
# Synset('serve.v.14')
# Synset('avail.n.01')
# Synset('in_common.r.01')
# Synset('in_common.r.01')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.02')
# Synset('beryllium.n.01')
# Synset('be.v.01')
# Synset('be.v.02')
# Synset('be.v.03')
# Synset('exist.v.01')
# Synset('be.v.05')
# Synset('equal.v.01')
# Synset('constitute.v.01')
# Synset('be.v.08')
# Synset('embody.v.02')
# Synset('be.v.10')
# Synset('be.v.11')
# Synset('be.v.12')
# Synset('cost.v.01')
# Synset('be.v.02')
# Synset('kind.n.01')
# Synset('kind.a.01')
# Synset('kind.s.02')
# Synset('kind.s.03')
# Synset('kind.s.03')
# Synset('duplicate.n.02')
# Synset('duplication.n.02')
# Synset('duplicate.n.02')
# Synset('uneconomical.s.01')
# Synset('uneconomical.s.02')
# Synset('uneconomical.s.01')
# Synset('output.n.02')
# Synset('return.n.06')
# Synset('yield.n.03')
# Synset('output.n.04')
# Synset('yield.v.01')
# Synset('give_way.v.03')
# Synset('render.v.04')
# Synset('concede.v.03')
# Synset('yield.v.05')
# Synset('move_over.v.01')
# Synset('give.v.09')
# Synset('concede.v.02')
# Synset('succumb.v.02')
# Synset('yield.v.10')
# Synset('give.v.33')
# Synset('yield.v.12')
# Synset('yield.v.13')
# Synset('move_over.v.01')
# Synset('system.n.01')
# Synset('system.n.02')
# Synset('system.n.03')
# Synset('system.n.04')
# Synset('arrangement.n.03')
# Synset('system.n.06')
# Synset('system.n.07')
# Synset('system.n.08')
# Synset('organization.n.05')
# Synset('system.n.01')
# Synset('ability.n.01')
# Synset('ability.n.02')
# Synset('ability.n.01')
# Synset('take_away.v.01')
# Synset('remove.v.01')
# Synset('take_away.v.03')
# Synset('take_away.v.04')
# Synset('take_out.v.12')
# Synset('remove.v.08')
# Synset('take_away.v.07')
# Synset('remove.v.08')
# Synset('cargo.n.01')
# Synset('freight.n.02')
# Synset('freight.n.03')
# Synset('freight.v.01')
# Synset('freight.v.02')
# Synset('freight.n.03')
# Synset('traffic.n.01')
# Synset('traffic.n.02')
# Synset('traffic.n.03')
# Synset('dealings.n.01')
# Synset('traffic.v.01')
# Synset('traffic.v.02')
# Synset('traffic.n.01')
# Synset('away.s.01')
# Synset('away.a.02')
# Synset('away.s.03')
# Synset('away.r.01')
# Synset('away.r.02')
# Synset('aside.r.02')
# Synset('away.r.04')
# Synset('off.r.02')
# Synset('away.r.06')
# Synset('away.r.07')
# Synset('away.r.08')
# Synset('away.r.09')
# Synset('away.r.10')
# Synset('aside.r.06')
# Synset('away.r.02')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.01')
# Synset('railway.n.01')
# Synset('railroad_track.n.01')
# Synset('railway.n.01')
# Synset('service.n.01')
# Synset('service.n.02')
# Synset('service.n.03')
# Synset('service.n.04')
# Synset('service.n.05')
# Synset('military_service.n.01')
# Synset('service.n.07')
# Synset('avail.n.01')
# Synset('service.n.09')
# Synset('servicing.n.01')
# Synset('service.n.11')
# Synset('serve.n.01')
# Synset('service.n.13')
# Synset('overhaul.n.01')
# Synset('service.n.15')
# Synset('service.v.01')
# Synset('service.v.02')
# Synset('serve.v.14')
# Synset('service.n.11')
# Synset('area.n.01')
# Synset('area.n.02')
# Synset('area.n.03')
# Synset('sphere.n.01')
# Synset('area.n.05')
# Synset('area.n.06')
# Synset('area.n.06')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.02')
# Synset('note.n.01')
# Synset('note.n.02')
# Synset('note.n.03')
# Synset('note.n.04')
# Synset('note.n.05')
# Synset('bill.n.03')
# Synset('note.n.07')
# Synset('eminence.n.01')
# Synset('note.n.09')
# Synset('note.v.01')
# Synset('notice.v.02')
# Synset('note.v.03')
# Synset('note.v.04')
# Synset('note.v.01')
# Synset('cargo.n.01')
# None
# Synset('traffic.n.01')
# Synset('traffic.n.02')
# Synset('traffic.n.03')
# Synset('dealings.n.01')
# Synset('traffic.v.01')
# Synset('traffic.v.02')
# Synset('traffic.n.03')
# Synset('most.a.01')
# Synset('most.a.02')
# Synset('most.r.01')
# Synset('most.r.02')
# Synset('about.r.07')
# Synset('most.a.01')
# Synset('susceptible.a.01')
# Synset('susceptible.s.02')
# Synset('susceptible.a.01')
# Synset('foray_into.v.01')
# Synset('foray_into.v.01')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.02')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.02')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.02')
# Synset('supply.n.01')
# Synset('supply.n.02')
# Synset('provision.n.02')
# Synset('supply.v.01')
# Synset('issue.v.02')
# Synset('provide.v.02')
# Synset('add.v.02')
# Synset('supply.n.02')
# Synset('anchor.n.01')
# Synset('anchor.n.02')
# Synset('anchor.n.03')
# Synset('anchor.v.01')
# Synset('anchor.v.02')
# Synset('anchor.n.02')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.02')
# Synset('gross.n.01')
# Synset('gross.n.02')
# Synset('gross.v.01')
# Synset('gross.a.01')
# Synset('gross.s.02')
# Synset('gross.s.03')
# Synset('megascopic.s.01')
# Synset('arrant.s.01')
# Synset('crude.s.02')
# Synset('crying.s.02')
# Synset('megascopic.s.01')
# Synset('gross.n.01')
# Synset('gross.n.02')
# Synset('gross.v.01')
# Synset('gross.a.01')
# Synset('gross.s.02')
# Synset('gross.s.03')
# Synset('megascopic.s.01')
# Synset('arrant.s.01')
# Synset('crude.s.02')
# Synset('crying.s.02')
# Synset('megascopic.s.01')
# Synset('supply.v.01')
# Synset('provide.v.02')
# Synset('provide.v.03')
# Synset('put_up.v.02')
# Synset('leave.v.06')
# Synset('provide.v.06')
# Synset('provide.v.07')
# Synset('leave.v.06')
# Synset('necessity.n.02')
# Synset('essential.s.01')
# Synset('essential.a.02')
# Synset('all-important.s.01')
# Synset('essential.a.04')
# Synset('substantive.a.02')
# Synset('necessity.n.02')
# Synset('cargo.n.01')
# None
# Synset('passenger.n.01')
# None
# Synset('service.n.01')
# Synset('service.n.02')
# Synset('service.n.03')
# Synset('service.n.04')
# Synset('service.n.05')
# Synset('military_service.n.01')
# Synset('service.n.07')
# Synset('avail.n.01')
# Synset('service.n.09')
# Synset('servicing.n.01')
# Synset('service.n.11')
# Synset('serve.n.01')
# Synset('service.n.13')
# Synset('overhaul.n.01')
# Synset('service.n.15')
# Synset('service.v.01')
# Synset('service.v.02')
# Synset('serve.v.14')
# Synset('service.v.01')
# Synset('stallion.n.01')
# Synset('entire.s.01')
# Synset('integral.s.02')
# Synset('entire.s.03')
# Synset('entire.s.04')
# Synset('integral.s.02')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.01')
# Synset('system.n.01')
# Synset('system.n.02')
# Synset('system.n.03')
# Synset('system.n.04')
# Synset('arrangement.n.03')
# Synset('system.n.06')
# Synset('system.n.07')
# Synset('system.n.08')
# Synset('organization.n.05')
# Synset('arrangement.n.03')
# Synset('new_york.n.01')
# Synset('new_york.n.02')
# Synset('new_york.n.03')
# Synset('new_york.n.01')
# Synset('sphere.n.01')
# Synset('sphere.n.02')
# Synset('sphere.n.03')
# Synset('sector.n.03')
# Synset('sphere.n.05')
# Synset('sphere.n.06')
# Synset('celestial_sphere.n.01')
# Synset('celestial_sphere.n.01')
# Synset('commuter.n.01')
# Synset('commuter.n.02')
# Synset('commuter.n.01')
# Synset('terminal.n.01')
# Synset('terminal.n.02')
# Synset('end.n.01')
# Synset('terminal.n.04')
# Synset('terminal.a.01')
# Synset('terminal.a.02')
# Synset('terminal.a.03')
# Synset('concluding.s.01')
# Synset('terminal.s.05')
# Synset('terminal.a.01')
# Synset('cargo.n.01')
# Synset('cargo.n.01')
# Synset('services.n.01')
# Synset('service.n.01')
# Synset('service.n.02')
# Synset('service.n.03')
# Synset('service.n.04')
# Synset('service.n.05')
# Synset('military_service.n.01')
# Synset('service.n.07')
# Synset('avail.n.01')
# Synset('service.n.09')
# Synset('servicing.n.01')
# Synset('service.n.11')
# Synset('serve.n.01')
# Synset('service.n.13')
# Synset('overhaul.n.01')
# Synset('service.n.15')
# Synset('service.v.01')
# Synset('service.v.02')
# Synset('serve.v.14')
# Synset('military_service.n.01')
# Synset('services.n.01')
# Synset('service.n.01')
# Synset('service.n.02')
# Synset('service.n.03')
# Synset('service.n.04')
# Synset('service.n.05')
# Synset('military_service.n.01')
# Synset('service.n.07')
# Synset('avail.n.01')
# Synset('service.n.09')
# Synset('servicing.n.01')
# Synset('service.n.11')
# Synset('serve.n.01')
# Synset('service.n.13')
# Synset('overhaul.n.01')
# Synset('service.n.15')
# Synset('service.v.01')
# Synset('service.v.02')
# Synset('serve.v.14')
# Synset('military_service.n.01')
# Synset('exist.v.01')
# Synset('exist.v.02')
# Synset('exist.v.01')
# Synset('kept_up.s.01')
# None
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.03')
# Synset('rich_person.n.01')
# Synset('have.v.01')
# Synset('have.v.02')
# Synset('experience.v.03')
# Synset('own.v.01')
# Synset('get.v.03')
# Synset('consume.v.02')
# Synset('have.v.07')
# Synset('hold.v.03')
# Synset('have.v.09')
# Synset('have.v.10')
# Synset('have.v.11')
# Synset('have.v.12')
# Synset('induce.v.02')
# Synset('accept.v.02')
# Synset('receive.v.01')
# Synset('suffer.v.02')
# Synset('have.v.17')
# Synset('give_birth.v.01')
# Synset('take.v.35')
# Synset('get.v.03')
# Synset('gross.n.01')
# Synset('gross.n.02')
# Synset('gross.v.01')
# Synset('gross.a.01')
# Synset('gross.s.02')
# Synset('gross.s.03')
# Synset('megascopic.s.01')
# Synset('arrant.s.01')
# Synset('crude.s.02')
# Synset('crying.s.02')
# Synset('megascopic.s.01')
# Synset('brand.n.02')
# Synset('shuffle.n.01')
# Synset('make.v.01')
# Synset('make.v.02')
# Synset('make.v.03')
# Synset('induce.v.02')
# Synset('cause.v.01')
# Synset('produce.v.02')
# Synset('draw.v.04')
# Synset('make.v.08')
# Synset('create.v.05')
# Synset('gain.v.08')
# Synset('do.v.08')
# Synset('form.v.02')
# Synset('reach.v.07')
# Synset('make.v.14')
# Synset('make.v.15')
# Synset('make.v.16')
# Synset('construct.v.01')
# Synset('make.v.18')
# Synset('make.v.19')
# Synset('name.v.03')
# Synset('have.v.17')
# Synset('reach.v.01')
# Synset('lay_down.v.01')
# Synset('make.v.24')
# Synset('make.v.25')
# Synset('hold.v.03')
# Synset('make.v.27')
# Synset('take.v.27')
# Synset('stool.v.04')
# Synset('make.v.30')
# Synset('make.v.31')
# Synset('make.v.32')
# Synset('make.v.33')
# Synset('make.v.34')
# Synset('make.v.35')
# Synset('make.v.36')
# Synset('make.v.37')
# Synset('make.v.38')
# Synset('cook.v.02')
# Synset('seduce.v.01')
# Synset('make.v.41')
# Synset('make.v.42')
# Synset('make.v.43')
# Synset('make.v.44')
# Synset('make.v.45')
# Synset('make.v.46')
# Synset('make.v.47')
# Synset('make.v.48')
# Synset('make.v.49')
# Synset('make.v.02')
# Synset('possible.n.01')
# Synset('possible.n.02')
# Synset('possible.a.01')
# Synset('potential.a.01')
# Synset('possible.n.01')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.01')
# Synset('today.n.01')
# Synset('today.n.02')
# Synset('nowadays.r.01')
# Synset('today.r.02')
# Synset('today.n.01')
# Synset('pull_off.v.03')
# Synset('manage.v.02')
# Synset('cope.v.01')
# Synset('oversee.v.01')
# Synset('wangle.v.01')
# Synset('do.v.11')
# Synset('wield.v.02')
# Synset('pull_off.v.03')
# Synset('sixty.n.01')
# Synset('sixty.s.01')
# Synset('sixty.n.01')
# Synset('percentage.n.01')
# Synset('share.n.01')
# Synset('percentage.n.01')
# Synset('southbound.s.01')
# Synset('southbound.s.01')
# Synset('commuter_traffic.n.01')
# Synset('commuter_traffic.n.01')
# Synset('semen.n.01')
# Synset('come.v.01')
# Synset('arrive.v.01')
# Synset('come.v.03')
# Synset('come.v.04')
# Synset('come.v.05')
# Synset('come.v.06')
# Synset('issue_forth.v.01')
# Synset('hail.v.02')
# Synset('come.v.09')
# Synset('come.v.10')
# Synset('come.v.11')
# Synset('fall.v.04')
# Synset('come.v.13')
# Synset('total.v.01')
# Synset('come.v.15')
# Synset('come.v.16')
# Synset('occur.v.02')
# Synset('derive.v.05')
# Synset('do.v.04')
# Synset('come.v.20')
# Synset('come.v.21')
# Synset('come.v.01')
# Synset('new_york.n.01')
# Synset('new_york.n.02')
# Synset('new_york.n.03')
# Synset('new_york.n.01')
# Synset('beryllium.n.01')
# Synset('be.v.01')
# Synset('be.v.02')
# Synset('be.v.03')
# Synset('exist.v.01')
# Synset('be.v.05')
# Synset('equal.v.01')
# Synset('constitute.v.01')
# Synset('be.v.08')
# Synset('embody.v.02')
# Synset('be.v.10')
# Synset('be.v.11')
# Synset('be.v.12')
# Synset('cost.v.01')
# Synset('be.v.05')
# Synset('fourteen.n.01')
# Synset('fourteen.s.01')
# Synset('fourteen.n.01')
# Synset('million.n.01')
# Synset('million.n.02')
# Synset('million.s.01')
# Synset('million.n.01')
# Synset('operation.n.01')
# Synset('operation.n.02')
# Synset('operation.n.03')
# Synset('operation.n.04')
# Synset('operation.n.05')
# Synset('operation.n.06')
# Synset('operation.n.07')
# Synset('operation.n.08')
# Synset('process.n.02')
# Synset('mathematical_process.n.01')
# Synset('operation.n.11')
# Synset('operation.n.06')
# Synset('necessitate.v.01')
# Synset('necessitate.v.02')
# Synset('necessitate.v.01')
# Synset('employee.n.01')
# Synset('employee.n.01')
# Synset('work_at.v.01')
# Synset('work_at.v.01')
# Synset('commuter_traffic.n.01')
# Synset('commuter_traffic.n.01')
# Synset('wholly.r.01')
# Synset('entirely.r.02')
# Synset('wholly.r.01')
# Synset('reverse.n.01')
# Synset('reverse.n.02')
# Synset('reverse.n.03')
# Synset('reverse.n.04')
# Synset('reverse.n.05')
# Synset('reversion.n.04')
# Synset('change_by_reversal.v.01')
# Synset('turn_back.v.05')
# Synset('overrule.v.01')
# Synset('revoke.v.02')
# Synset('invert.v.02')
# Synset('rearward.s.02')
# Synset('reverse.a.02')
# Synset('inverse.s.01')
# Synset('change_by_reversal.v.01')
# Synset('phase.n.01')
# Synset('phase.n.02')
# Synset('phase.n.03')
# Synset('phase.n.04')
# Synset('phase.v.01')
# Synset('phase.v.02')
# Synset('phase.v.02')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.02')
# Synset('operation.n.01')
# Synset('operation.n.02')
# Synset('operation.n.03')
# Synset('operation.n.04')
# Synset('operation.n.05')
# Synset('operation.n.06')
# Synset('operation.n.07')
# Synset('operation.n.08')
# Synset('process.n.02')
# Synset('mathematical_process.n.01')
# Synset('operation.n.11')
# Synset('operation.n.02')
# Synset('induce.v.01')
# Synset('induce.v.02')
# Synset('induce.v.03')
# Synset('induce.v.04')
# Synset('induce.v.05')
# Synset('induce.v.03')
# Synset('serious.a.01')
# Synset('serious.s.02')
# Synset('dangerous.s.02')
# Synset('good.s.16')
# Synset('unplayful.a.01')
# Synset('serious.s.06')
# Synset('serious.s.06')
# Synset('economic.a.01')
# Synset('economic.a.02')
# Synset('economic.s.03')
# Synset('economic.s.04')
# Synset('economic.s.05')
# Synset('economic.a.01')
# Synset('consequence.n.01')
# Synset('consequence.n.02')
# Synset('consequence.n.03')
# Synset('consequence.n.01')
# Synset('railway.n.01')
# Synset('railroad_track.n.01')
# None
# Synset('citizenry.n.01')
# Synset('citizenry.n.01')
# Synset('day.n.01')
# Synset('day.n.02')
# Synset('day.n.03')
# Synset('day.n.04')
# Synset('day.n.05')
# Synset('day.n.06')
# Synset('day.n.07')
# Synset('sidereal_day.n.01')
# Synset('day.n.09')
# Synset('day.n.10')
# Synset('day.n.07')
# Synset('supply.n.01')
# Synset('supply.n.02')
# Synset('provision.n.02')
# Synset('supply.v.01')
# Synset('issue.v.02')
# Synset('provide.v.02')
# Synset('add.v.02')
# Synset('supply.n.01')
# Synset('efficient.a.01')
# Synset('effective.s.02')
# Synset('effective.s.02')
# Synset('reasonably.r.01')
# Synset('sanely.r.01')
# Synset('reasonably.r.01')
# Synset('transportation_system.n.01')
# Synset('transportation_system.n.01')
# Synset('city.n.01')
# Synset('city.n.02')
# Synset('city.n.03')
# Synset('city.n.01')
# Synset('feasible.s.01')
# None
# Synset('option.n.01')
# Synset('option.n.02')
# Synset('choice.n.02')
# Synset('option.n.01')
# Synset('potentially.r.01')
# Synset('potentially.r.01')
# Synset('dangerous.a.01')
# Synset('dangerous.s.02')
# Synset('dangerous.s.02')
# Synset('amalgamation.n.01')
# Synset('amalgamation.n.01')
# Synset('scheme.n.01')
# Synset('dodge.n.03')
# Synset('system.n.02')
# Synset('schema.n.01')
# Synset('outline.n.03')
# Synset('scheme.v.01')
# Synset('scheme.v.02')
# Synset('scheme.n.01')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.01')
# Synset('remark.n.01')
# Synset('comment.n.02')
# Synset('gossip.n.02')
# Synset('comment.v.01')
# Synset('comment.v.02')
# Synset('gloss.v.02')
# Synset('remark.n.01')
# Synset('logic.n.01')
# Synset('logic.n.02')
# Synset('logic.n.03')
# Synset('logic.n.04')
# Synset('logic.n.05')
# Synset('logic.n.01')
# Synset('make.v.03')
# Synset('create.v.02')
# Synset('create.v.03')
# Synset('create.v.04')
# Synset('create.v.05')
# Synset('produce.v.02')
# Synset('make.v.03')
# Synset('strong.a.01')
# Synset('strong.s.02')
# Synset('potent.s.02')
# Synset('potent.a.03')
# Synset('impregnable.s.01')
# Synset('solid.s.07')
# Synset('strong.s.07')
# Synset('hard.s.10')
# Synset('strong.s.09')
# Synset('firm.s.03')
# Synset('impregnable.s.01')
# Synset('balance.v.01')
# Synset('balance.v.02')
# Synset('poise.v.04')
# Synset('balance.v.04')
# Synset('balanced.a.01')
# Synset('balanced.a.01')
# Synset('competitive.a.01')
# Synset('competitive.s.02')
# Synset('competitive.s.03')
# Synset('competitive.a.01')
# Synset('two.n.01')
# Synset('deuce.n.04')
# Synset('two.s.01')
# Synset('two.n.01')
# Synset('system.n.01')
# Synset('system.n.02')
# Synset('system.n.03')
# Synset('system.n.04')
# Synset('arrangement.n.03')
# Synset('system.n.06')
# Synset('system.n.07')
# Synset('system.n.08')
# Synset('organization.n.05')
# Synset('system.n.01')
# Synset('railway.n.01')
# Synset('railroad_track.n.01')
# Synset('railway.n.01')
# Synset('service.n.01')
# Synset('service.n.02')
# Synset('service.n.03')
# Synset('service.n.04')
# Synset('service.n.05')
# Synset('military_service.n.01')
# Synset('service.n.07')
# Synset('avail.n.01')
# Synset('service.n.09')
# Synset('servicing.n.01')
# Synset('service.n.11')
# Synset('serve.n.01')
# Synset('service.n.13')
# Synset('overhaul.n.01')
# Synset('service.n.15')
# Synset('service.v.01')
# Synset('service.v.02')
# Synset('serve.v.14')
# Synset('service.n.11')
# Synset('east.n.01')
# Synset('east.n.02')
# Synset('east.n.03')
# Synset('east.n.04')
# Synset('east.n.05')
# Synset('east.a.01')
# Synset('east.r.01')
# Synset('east.n.03')
# Synset('exist.v.01')
# Synset('exist.v.02')
# Synset('exist.v.02')
# Synset('sol.n.03')
# Synset('so.r.01')
# Synset('so.r.02')
# Synset('so.r.03')
# Synset('so.r.04')
# Synset('so.r.05')
# Synset('thus.r.02')
# Synset('so.r.07')
# Synset('then.r.01')
# Synset('therefore.r.01')
# Synset('indeed.r.01')
# Synset('therefore.r.01')
# Synset('group.n.01')
# Synset('group.n.02')
# Synset('group.n.03')
# Synset('group.v.01')
# Synset('group.v.02')
# Synset('group.n.02')
# Synset('publicly.r.01')
# Synset('publicly.r.02')
# Synset('publicly.r.01')
# Synset('give.n.01')
# Synset('give.v.01')
# Synset('yield.v.01')
# Synset('give.v.03')
# Synset('give.v.04')
# Synset('give.v.05')
# Synset('hold.v.03')
# Synset('give.v.07')
# Synset('give.v.08')
# Synset('give.v.09')
# Synset('give.v.10')
# Synset('render.v.04')
# Synset('impart.v.01')
# Synset('establish.v.05')
# Synset('give.v.14')
# Synset('give.v.15')
# Synset('sacrifice.v.01')
# Synset('pass.v.05')
# Synset('give.v.18')
# Synset('give.v.19')
# Synset('give.v.20')
# Synset('give.v.21')
# Synset('grant.v.05')
# Synset('move_over.v.01')
# Synset('feed.v.02')
# Synset('contribute.v.02')
# Synset('collapse.v.01')
# Synset('give.v.27')
# Synset('give.v.28')
# Synset('give.v.29')
# Synset('afford.v.04')
# Synset('give.v.31')
# Synset('give.v.32')
# Synset('give.v.33')
# Synset('give.v.34')
# Synset('give.v.35')
# Synset('give.v.36')
# Synset('give.v.37')
# Synset('give.v.38')
# Synset('give.v.39')
# Synset('give.v.40')
# Synset('give.v.41')
# Synset('give.v.42')
# Synset('give.v.43')
# Synset('give.v.44')
# Synset('give.n.01')
# Synset('approach.n.01')
# Synset('approach.n.02')
# Synset('access.n.03')
# Synset('approach_path.n.01')
# Synset('approach.n.05')
# Synset('overture.n.03')
# Synset('approach.n.07')
# Synset('approach.n.08')
# Synset('approach.n.09')
# Synset('approach.v.01')
# Synset('border_on.v.01')
# Synset('set_about.v.01')
# Synset('approach.v.04')
# Synset('approach.v.05')
# Synset('approach.n.01')
# Synset('sketch.n.01')
# Synset('sketch.n.02')
# Synset('sketch.n.03')
# Synset('cartoon.n.01')
# Synset('sketch.v.01')
# Synset('sketch.v.02')
# Synset('sketch.n.01')
# Synset('here.n.01')
# Synset('hera.n.01')
# Synset('here.s.01')
# Synset('here.r.01')
# Synset('here.r.02')
# Synset('here.r.03')
# Synset('here.r.04')
# Synset('hera.n.01')
# Synset('detail.v.01')
# Synset('detail.v.02')
# Synset('detailed.s.01')
# Synset('detailed.s.01')
# Synset('survey.n.01')
# Synset('sketch.n.03')
# Synset('view.n.03')
# Synset('survey.v.01')
# Synset('survey.v.02')
# Synset('surveil.v.01')
# Synset('review.v.03')
# Synset('survey.v.05')
# Synset('survey.v.06')
# Synset('view.n.03')
# Synset('design.n.01')
# Synset('design.n.02')
# Synset('blueprint.n.01')
# Synset('design.n.04')
# Synset('purpose.n.01')
# Synset('design.n.06')
# Synset('invention.n.01')
# Synset('plan.v.03')
# Synset('design.v.02')
# Synset('design.v.03')
# Synset('design.v.04')
# Synset('design.v.05')
# Synset('design.v.06')
# Synset('design.v.07')
# Synset('design.v.03')
# Synset('beryllium.n.01')
# Synset('be.v.01')
# Synset('be.v.02')
# Synset('be.v.03')
# Synset('exist.v.01')
# Synset('be.v.05')
# Synset('equal.v.01')
# Synset('constitute.v.01')
# Synset('be.v.08')
# Synset('embody.v.02')
# Synset('be.v.10')
# Synset('be.v.11')
# Synset('be.v.12')
# Synset('cost.v.01')
# Synset('be.v.05')
# Synset('well.n.01')
# Synset('well.n.02')
# Synset('well.n.03')
# Synset('well.n.04')
# Synset('well.n.05')
# Synset('well.v.01')
# Synset('well.a.01')
# Synset('good.s.13')
# Synset('well.s.03')
# Synset('well.r.01')
# Synset('well.r.02')
# Synset('well.r.03')
# Synset('well.r.04')
# Synset('well.r.05')
# Synset('well.r.06')
# Synset('well.r.07')
# Synset('well.r.08')
# Synset('well.r.09')
# Synset('well.r.10')
# Synset('well.r.11')
# Synset('well.r.12')
# Synset('well.r.13')
# Synset('well.n.04')
# Synset('afoot.s.01')
# Synset('afoot.s.02')
# Synset('afoot.r.01')
# Synset('afoot.s.02')
# Synset('army_for_the_liberation_of_rwanda.n.01')
# Synset('far.a.01')
# Synset('far.s.02')
# Synset('far.s.03')
# Synset('far.s.04')
# Synset('far.r.01')
# Synset('far.r.02')
# Synset('far.r.03')
# Synset('far.r.04')
# Synset('far.r.05')
# Synset('far.a.01')
# Synset('survey.n.01')
# Synset('sketch.n.03')
# Synset('view.n.03')
# Synset('survey.v.01')
# Synset('survey.v.02')
# Synset('surveil.v.01')
# Synset('review.v.03')
# Synset('survey.v.05')
# Synset('survey.v.06')
# Synset('surveil.v.01')
# Synset('bespeak.v.01')
# Synset('indicate.v.02')
# Synset('indicate.v.03')
# Synset('argue.v.03')
# Synset('indicate.v.05')
# Synset('bespeak.v.01')
# Synset('doubt.n.01')
# Synset('doubt.n.02')
# Synset('doubt.v.01')
# Synset('doubt.v.02')
# Synset('doubt.n.01')
# Synset('economy.n.01')
# Synset('economy.n.02')
# Synset('economy.n.03')
# Synset('economy.n.04')
# Synset('economy.n.03')
# Synset('consequence.n.01')
# Synset('solution.n.02')
# Synset('result.n.03')
# Synset('resultant_role.n.01')
# Synset('result.v.01')
# Synset('leave.v.07')
# Synset('result.v.03')
# Synset('solution.n.02')
# Synset('beryllium.n.01')
# Synset('be.v.01')
# Synset('be.v.02')
# Synset('be.v.03')
# Synset('exist.v.01')
# Synset('be.v.05')
# Synset('equal.v.01')
# Synset('constitute.v.01')
# Synset('be.v.08')
# Synset('embody.v.02')
# Synset('be.v.10')
# Synset('be.v.11')
# Synset('be.v.12')
# Synset('cost.v.01')
# Synset('be.v.01')
# Synset('unprecedented.a.01')
# Synset('unprecedented.a.01')
# Synset('benefit.n.01')
# Synset('benefit.n.02')
# Synset('benefit.n.03')
# Synset('profit.v.01')
# Synset('benefit.v.02')
# Synset('benefit.n.01')
# Synset('railway.n.01')
# Synset('railroad_track.n.01')
# Synset('railway.n.01')
# Synset('refer.v.02')
# Synset('concern.v.02')
# Synset('concerned.a.01')
# Synset('concerned.s.02')
# Synset('implicated.s.01')
# Synset('concerned.s.02')
# Synset('investor.n.01')
# Synset('investor.n.01')
# Synset('customer.n.01')
# None
# Synset('user.n.01')
# Synset('exploiter.n.01')
# Synset('drug_user.n.01')
# Synset('user.n.01')
# Synset('populace.n.01')
# Synset('populace.n.01')
# Synset('then.n.01')
# Synset('then.s.01')
# Synset('then.r.01')
# Synset('then.r.02')
# Synset('then.r.03')
# Synset('then.r.02')
# Synset('abandon.n.01')
# Synset('wildness.n.01')
# Synset('abandon.v.01')
# Synset('abandon.v.02')
# Synset('vacate.v.02')
# Synset('abandon.v.04')
# Synset('abandon.v.05')
# Synset('abandon.v.04')
# Synset('survey.n.01')
# Synset('sketch.n.03')
# Synset('view.n.03')
# Synset('survey.v.01')
# Synset('survey.v.02')
# Synset('surveil.v.01')
# Synset('review.v.03')
# Synset('survey.v.05')
# Synset('survey.v.06')
# Synset('view.n.03')
# Synset('bright.a.01')
# Synset('bright.s.02')
# Synset('bright.s.03')
# Synset('bright.s.04')
# Synset('bright.s.05')
# Synset('bright.s.06')
# Synset('undimmed.a.01')
# Synset('bright.s.08')
# Synset('bright.s.09')
# Synset('bright.s.10')
# Synset('brilliantly.r.01')
# Synset('bright.s.10')
# Synset('expectation.n.01')
# Synset('anticipation.n.04')
# Synset('expectation.n.03')
# Synset('arithmetic_mean.n.01')
# Synset('expectation.n.01')
# Synset('refer.v.02')
# Synset('concern.v.02')
# Synset('concerned.a.01')
# Synset('concerned.s.02')
# Synset('implicated.s.01')
# Synset('concern.v.02')
# Synset('enter.v.01')
# Synset('enter.v.02')
# Synset('enroll.v.01')
# Synset('figure.v.02')
# Synset('record.v.01')
# Synset('enter.v.06')
# Synset('accede.v.02')
# Synset('insert.v.01')
# Synset('embark.v.02')
# Synset('accede.v.02')
# Synset('negotiation.n.01')
# ...
# Synset('deal.v.06')
# Synset('sell.v.05')
# Synset('sell.v.06')
# Synset('sell.v.07')
# Synset('betray.v.02')
# Synset('sell.v.01')
# Synset('plan.n.01')
# Synset('design.n.02')
# Synset('plan.n.03')
# Synset('plan.v.01')
# Synset('plan.v.02')
# Synset('plan.v.03')
# Synset('design.v.04')
# Synset('plan.n.01')
# Synset('point_of_view.n.01')
# Synset('point_of_view.n.02')
# Synset('point_of_view.n.01')
# Synset('attempt.n.01')
# Synset('effort.n.02')
# Synset('feat.n.01')
# Synset('campaign.n.02')
# Synset('attempt.n.01')
# Synset('money.n.01')
# Synset('money.n.02')
# Synset('money.n.03')
# Synset('money.n.01')
# Synset('effectiveness.n.01')
# Synset('potency.n.02')
# Synset('effectiveness.n.01')
# Synset('practically.r.01')
# Synset('practically.r.02')
# Synset('much.r.04')
# Synset('practically.r.01')
# Synset('all.a.01')
# Synset('all.s.02')
# Synset('wholly.r.01')
# Synset('all.a.01')
# Synset('prognosis.n.01')
# Synset('prognosis.n.02')
# Synset('prognosis.n.01')
# Synset('mention.n.01')
# Synset('citation.n.03')
# Synset('mention.n.03')
# Synset('mention.v.01')
# Synset('note.v.01')
# Synset('mention.v.03')
# Synset('mention.v.01')
# Synset('fresh.a.01')
# Synset('fresh.s.02')
# Synset('bracing.s.01')
# Synset('fresh.s.04')
# Synset('fresh.a.05')
# Synset('fresh.a.06')
# Synset('fresh.s.07')
# Synset('fresh.s.08')
# Synset('fresh.s.09')
# Synset('clean.s.04')
# Synset('fresh.s.11')
# Synset('fresh.s.12')
# Synset('newly.r.01')
# Synset('fresh.s.04')
# Synset('excite.v.01')
# Synset('stimulate.v.01')
# Synset('stimulate.v.06')
# Synset('agitate.v.02')
# Synset('arouse.v.07')
# Synset('stimulate.v.03')
# Synset('excite.v.07')
# Synset('excite.v.08')
# Synset('exciting.a.01')
# Synset('exciting.s.02')
# Synset('agitate.v.02')
# Synset('merchandise.n.01')
# Synset('trade.v.01')
# Synset('merchandise.n.01')
# Synset('horizon.n.01')
# Synset('horizon.n.02')
# Synset('horizon.n.03')
# Synset('horizon.n.04')
# Synset('horizon.n.01')
# Synset('beryllium.n.01')
# Synset('be.v.01')
# Synset('be.v.02')
# Synset('be.v.03')
# Synset('exist.v.01')
# Synset('be.v.05')
# Synset('equal.v.01')
# Synset('constitute.v.01')
# Synset('be.v.08')
# Synset('embody.v.02')
# Synset('be.v.10')
# Synset('be.v.11')
# Synset('be.v.12')
# Synset('cost.v.01')
# Synset('be.v.01')
# Synset('market.n.01')
# Synset('market.n.02')
# Synset('grocery_store.n.01')
# Synset('market.n.04')
# Synset('marketplace.n.02')
# Synset('market.v.01')
# Synset('market.v.02')
# Synset('market.v.03')
# Synset('commercialize.v.02')
# Synset('market.v.01')
# Synset('sale.n.01')
# Synset('sale.n.02')
# Synset('sale.n.03')
# Synset('sale.n.04')
# Synset('sale.n.05')
# Synset('sale.n.01')
# Synset('fresh.a.01')
# Synset('fresh.s.02')
# Synset('bracing.s.01')
# Synset('fresh.s.04')
# Synset('fresh.a.05')
# Synset('fresh.a.06')
# Synset('fresh.s.07')
# Synset('fresh.s.08')
# Synset('fresh.s.09')
# Synset('clean.s.04')
# Synset('fresh.s.11')
# Synset('fresh.s.12')
# Synset('newly.r.01')
# Synset('fresh.s.07')
# Synset('merchandise.n.01')
# Synset('trade.v.01')
# Synset('trade.v.01')
# Synset('competition.n.01')
# Synset('contest.n.01')
# Synset('competition.n.03')
# Synset('rival.n.01')
# Synset('competition.n.03')
# Synset('beat.n.01')
# Synset('pulse.n.02')
# Synset('rhythm.n.01')
# Synset('beat.n.04')
# Synset('beatnik.n.01')
# Synset('beat.n.06')
# Synset('meter.n.03')
# Synset('beat.n.08')
# Synset('beat.n.09')
# Synset('beat.n.10')
# Synset('beat.v.01')
# Synset('beat.v.02')
# Synset('beat.v.03')
# Synset('beat.v.04')
# Synset('beat.v.05')
# Synset('drum.v.01')
# Synset('beat.v.07')
# Synset('beat.v.08')
# Synset('beat.v.09')
# Synset('beat.v.10')
# Synset('beat.v.11')
# Synset('beat.v.12')
# Synset('beat.v.13')
# Synset('tick.v.02')
# Synset('beat.v.15')
# Synset('beat.v.16')
# Synset('pulsate.v.02')
# Synset('beat.v.18')
# Synset('beat.v.19')
# Synset('beat.v.20')
# Synset('outwit.v.01')
# Synset('perplex.v.01')
# Synset('exhaust.v.01')
# Synset('all_in.s.01')
# Synset('all_in.s.01')
# Synset('excite.v.01')
# Synset('stimulate.v.01')
# Synset('stimulate.v.06')
# Synset('agitate.v.02')
# Synset('arouse.v.07')
# Synset('stimulate.v.03')
# Synset('excite.v.07')
# Synset('excite.v.08')
# Synset('exciting.a.01')
# Synset('exciting.s.02')
# Synset('stimulate.v.03')
# Synset('fresh.a.01')
# Synset('fresh.s.02')
# Synset('bracing.s.01')
# Synset('fresh.s.04')
# Synset('fresh.a.05')
# Synset('fresh.a.06')
# Synset('fresh.s.07')
# Synset('fresh.s.08')
# Synset('fresh.s.09')
# Synset('clean.s.04')
# Synset('fresh.s.11')
# Synset('fresh.s.12')
# Synset('newly.r.01')
# Synset('fresh.s.04')
# Synset('merchandise.n.01')
# Synset('trade.v.01')
# Synset('trade.v.01')
# Synset('era.n.01')
# Synset('era.n.02')
# Synset('earned_run_average.n.01')
# Synset('era.n.02')
# Synset('rich_person.n.01')
# Synset('have.v.01')
# Synset('have.v.02')
# Synset('experience.v.03')
# Synset('own.v.01')
# Synset('get.v.03')
# Synset('consume.v.02')
# Synset('have.v.07')
# Synset('hold.v.03')
# Synset('have.v.09')
# Synset('have.v.10')
# Synset('have.v.11')
# Synset('have.v.12')
# Synset('induce.v.02')
# Synset('accept.v.02')
# Synset('receive.v.01')
# Synset('suffer.v.02')
# Synset('have.v.17')
# Synset('give_birth.v.01')
# Synset('take.v.35')
# Synset('get.v.03')
# Synset('real_number.n.01')
# Synset('real.n.02')
# Synset('real.n.03')
# Synset('real.a.01')
# Synset('real.a.02')
# Synset('real.s.03')
# Synset('real.s.04')
# Synset('actual.s.03')
# Synset('real.a.06')
# Synset('substantial.a.03')
# Synset('real.s.08')
# Synset('veridical.s.01')
# Synset('very.r.01')
# Synset('real.a.02')
# Synset('concern.n.01')
# Synset('concern.n.02')
# Synset('concern.n.03')
# Synset('concern.n.04')
# Synset('business.n.01')
# Synset('refer.v.02')
# Synset('concern.v.02')
# Synset('concern.n.01')
# Synset('in_store.s.01')
# Synset('in_store.s.01')
# Synset('on_the_other_hand.r.01')
# Synset('on_the_other_hand.r.01')
# Synset('procedure.n.01')
# Synset('operation.n.07')
# Synset('routine.n.03')
# Synset('procedure.n.04')
# Synset('procedure.n.01')
# Synset('old.n.01')
# Synset('old.a.01')
# Synset('old.a.02')
# Synset('old.s.03')
# Synset('old.s.04')
# Synset('erstwhile.s.01')
# Synset('honest-to-god.s.01')
# Synset('old.s.07')
# Synset('previous.s.01')
# Synset('old.n.01')
# Synset('merchandise.n.01')
# Synset('trade.v.01')
# Synset('trade.v.01')
# Synset('bring_in.v.01')
# Synset('gain.v.08')
# Synset('fetch.v.02')
# Synset('bring_in.v.04')
# Synset('bring_in.v.05')
# Synset('fetch.v.02')
# Synset('new.a.01')
# Synset('fresh.s.04')
# Synset('raw.s.12')
# Synset('new.s.04')
# Synset('new.s.05')
# Synset('new.a.06')
# Synset('newfangled.s.01')
# Synset('new.s.08')
# Synset('modern.s.05')
# Synset('new.s.10')
# Synset('new.s.11')
# Synset('newly.r.01')
# Synset('fresh.s.04')
# Synset('beryllium.n.01')
# Synset('be.v.01')
# Synset('be.v.02')
# Synset('be.v.03')
# Synset('exist.v.01')
# Synset('be.v.05')
# Synset('equal.v.01')
# Synset('constitute.v.01')
# Synset('be.v.08')
# Synset('embody.v.02')
# Synset('be.v.10')
# Synset('be.v.11')
# Synset('be.v.12')
# Synset('cost.v.01')
# Synset('be.v.01')
# Synset('normally.r.01')
# None
# Synset('mighty.s.01')
# Synset('mighty.r.01')
# Synset('mighty.r.01')
# Synset('expensive.a.01')
# Synset('expensive.a.01')
# Synset('market.n.01')
# Synset('market.n.02')
# Synset('grocery_store.n.01')
# Synset('market.n.04')
# Synset('marketplace.n.02')
# Synset('market.v.01')
# Synset('market.v.02')
# Synset('market.v.03')
# Synset('commercialize.v.02')
# Synset('market.n.01')
# Synset('become.v.01')
# Synset('become.v.02')
# Synset('become.v.03')
# Synset('become.v.04')
# Synset('become.v.01')
# Synset('bigger.s.01')
# Synset('large.a.01')
# Synset('big.s.02')
# Synset('bad.s.02')
# Synset('big.s.04')
# Synset('big.s.05')
# Synset('big.s.06')
# Synset('boastful.s.01')
# Synset('big.s.08')
# Synset('adult.s.01')
# Synset('big.s.10')
# Synset('big.s.11')
# Synset('big.s.12')
# Synset('big.s.13')
# Synset('large.a.01')
# Synset('selling.n.01')
# Synset('sell.v.01')
# Synset('sell.v.02')
# Synset('sell.v.03')
# Synset('deal.v.06')
# Synset('sell.v.05')
# Synset('sell.v.06')
# Synset('sell.v.07')
# Synset('betray.v.02')
# Synset('sell.v.06')
# Synset('more.n.01')
# Synset('more.a.01')
# Synset('more.a.02')
# Synset('more.r.01')
# Synset('more.r.02')
# Synset('more.a.02')
# Synset('complex.n.01')
# Synset('complex.n.02')
# Synset('complex.n.03')
# Synset('building_complex.n.01')
# Synset('complex.a.01')
# Synset('complex.n.03')
# Synset('cost.n.01')
# Synset('monetary_value.n.01')
# Synset('price.n.03')
# Synset('cost.v.01')
# Synset('cost.v.02')
# Synset('price.n.03')
# Synset('mistake.n.01')
# Synset('mistake.n.02')
# Synset('error.n.07')
# Synset('mistake.v.01')
# Synset('err.v.01')
# Synset('mistake.n.01')
# Synset('become.v.01')
# Synset('become.v.02')
# Synset('become.v.03')
# Synset('become.v.04')
# Synset('become.v.04')
# Synset('increasingly.r.01')
# Synset('increasingly.r.01')
# Synset('bigger.s.01')
# Synset('large.a.01')
# Synset('big.s.02')
# Synset('bad.s.02')
# Synset('big.s.04')
# Synset('big.s.05')
# Synset('big.s.06')
# Synset('boastful.s.01')
# Synset('big.s.08')
# Synset('adult.s.01')
# Synset('big.s.10')
# Synset('big.s.11')
# Synset('big.s.12')
# Synset('big.s.13')
# Synset('large.a.01')
# Synset('merchandise.n.01')
# Synset('trade.v.01')
# Synset('merchandise.n.01')
# Synset('plan.n.01')
# Synset('program.n.02')
# Synset('broadcast.n.02')
# Synset('platform.n.02')
# Synset('program.n.05')
# Synset('course_of_study.n.01')
# Synset('program.n.07')
# Synset('program.n.08')
# Synset('program.v.01')
# Synset('program.v.02')
# Synset('program.n.02')
# Synset('commercial.n.01')
# Synset('commercial.a.01')
# Synset('commercial.a.02')
# Synset('commercial.s.03')
# Synset('commercial.s.03')
# Synset('world.n.03')
# Synset('reality.n.02')
# Synset('reality.n.03')
# Synset('reality.n.04')
# Synset('reality.n.03')
# Synset('market.n.01')
# Synset('market.n.02')
# Synset('grocery_store.n.01')
# Synset('market.n.04')
# Synset('marketplace.n.02')
# Synset('market.v.01')
# Synset('market.v.02')
# Synset('market.v.03')
# Synset('commercialize.v.02')
# Synset('market.n.02')
# Synset('regular.n.01')
# Synset('regular.n.02')
# Synset('regular.n.03')
# Synset('regular.n.04')
# Synset('regular.a.01')
# Synset('regular.s.02')
# Synset('regular.s.03')
# Synset('regular.s.04')
# Synset('regular.s.05')
# Synset('even.s.05')
# Synset('regular.s.07')
# Synset('regular.a.08')
# Synset('regular.a.09')
# Synset('unconstipated.a.01')
# Synset('even.s.04')
# Synset('regular.s.12')
# Synset('regular.s.13')
# Synset('regular.n.01')
# Synset('communication.n.01')
# Synset('communication.n.02')
# Synset('communication.n.03')
# Synset('communication.n.02')
# Synset('field.n.01')
# Synset('battlefield.n.01')
# Synset('field.n.03')
# Synset('discipline.n.01')
# Synset('field.n.05')
# Synset('field.n.06')
# Synset('sphere.n.01')
# Synset('playing_field.n.02')
# Synset('plain.n.01')
# Synset('field.n.10')
# Synset('field.n.11')
# Synset('field.n.12')
# Synset('field.n.13')
# Synset('field.n.14')
# Synset('field.n.15')
# Synset('field.n.16')
# Synset('airfield.n.01')
# Synset('field.v.01')
# Synset('field.v.02')
# Synset('field.v.03')
# Synset('field.v.04')
# Synset('sphere.n.01')
# Synset('meeting.n.01')
# Synset('meeting.n.02')
# Synset('meeting.n.03')
# Synset('meeting.n.04')
# Synset('merging.n.01')
# Synset('confluence.n.01')
# Synset('meet.v.01')
# Synset('meet.v.02')
# Synset('converge.v.01')
# Synset('meet.v.04')
# Synset('meet.v.05')
# Synset('meet.v.06')
# Synset('meet.v.07')
# Synset('meet.v.08')
# Synset('meet.v.09')
# Synset('meet.v.10')
# Synset('meet.v.11')
# Synset('suffer.v.10')
# Synset('touch.v.05')
# Synset('meet.v.05')
# Synset('sale.n.01')
# Synset('sale.n.02')
# Synset('sale.n.03')
# Synset('sale.n.04')
# Synset('sale.n.05')
# Synset('sale.n.05')
# Synset('selling.n.01')
# Synset('sell.v.01')
# Synset('sell.v.02')
# Synset('sell.v.03')
# Synset('deal.v.06')
# Synset('sell.v.05')
# Synset('sell.v.06')
# Synset('sell.v.07')
# Synset('betray.v.02')
# Synset('sell.v.01')
# Synset('force.n.01')
# Synset('force.n.02')
# Synset('force.n.03')
# Synset('force.n.04')
# Synset('military_unit.n.01')
# Synset('violence.n.01')
# Synset('power.n.05')
# Synset('force.n.08')
# Synset('effect.n.05')
# Synset('force_out.n.01')
# Synset('coerce.v.01')
# Synset('impel.v.01')
# Synset('push.v.01')
# Synset('force.v.04')
# Synset('wedge.v.02')
# Synset('force.v.06')
# Synset('pull.v.01')
# Synset('force.v.08')
# Synset('storm.v.02')
# Synset('coerce.v.01')
# Synset('people.n.01')
# Synset('citizenry.n.01')
# Synset('people.n.03')
# Synset('multitude.n.03')
# Synset('people.v.01')
# Synset('people.v.02')
# Synset('people.n.03')
# Synset('technical.n.01')
# Synset('technical_foul.n.01')
# Synset('technical.a.01')
# Synset('technical.a.02')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> print(accuracy(simple_lesk, data), "%")
#
# /home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb Cell 7 in accuracy(algorithm, data)
#       <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> word = data['sense_full'][i]
#       <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> word = word.split('.')[0]
# ----> <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> pred_sense = algorithm(context, word)
#       <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> print(pred_sense)
#       <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> if pred_sense is None:
#
# /home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb Cell 7 in simple_lesk(cotext_sentence, amb_word)
#       <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> print(sense)
#       <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> signature = set()
# ---> <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a> sene_definitions = nltk.word_tokenize(sense.definition())
#      <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> signature = signature.union(set(sene_definitions))
#      <a href='vscode-notebook-cell:/home/abhishek/Desktop/Word-Sense-Disambiguation/Baseline/codeLEST.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> signature = signature.union(set(sense.lemma_names()))
#
# File ~/miniconda3/lib/python3.10/site-packages/nltk/tokenize/__init__.py:130, in word_tokenize(text, language, preserve_line)
#     115 """
#     116 Return a tokenized copy of *text*,
#     117 using NLTK's recommended word tokenizer
#    (...)
#     127 :type preserve_line: bool
#     128 """
#     129 sentences = [text] if preserve_line else sent_tokenize(text, language)
# --> 130 return [
#     131     token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132 ]
#
# File ~/miniconda3/lib/python3.10/site-packages/nltk/tokenize/__init__.py:131, in <listcomp>(.0)
#     115 """
#     116 Return a tokenized copy of *text*,
#     117 using NLTK's recommended word tokenizer
#    (...)
#     127 :type preserve_line: bool
#     128 """
#     129 sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130 return [
# --> 131     token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132 ]
#
# File ~/miniconda3/lib/python3.10/site-packages/nltk/tokenize/destructive.py:181, in NLTKWordTokenizer.tokenize(self, text, convert_parentheses, return_str)
#     178     text = regexp.sub(substitution, text)
#     180 for regexp in self.CONTRACTIONS2:
# --> 181     text = regexp.sub(r" \1 \2 ", text)
#     182 for regexp in self.CONTRACTIONS3:
#     183     text = regexp.sub(r" \1 \2 ", text)
#
# File ~/miniconda3/lib/python3.10/re.py:324, in _subx(pattern, template)
#     321     template = sre_parse.parse_template(template, pattern)
#     322     return sre_parse.expand_template(template, match)
# --> 324 def _subx(pattern, template):
#     325     # internal: Pattern.sub/subn implementation helper
#     326     template = _compile_repl(template, pattern)
#     327     if not template[0] and len(template[1]) == 1:
#     328         # literal replacement
#
# KeyboardInterrupt:

# %%
import pprint
import numpy as np
import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords

# %%
stopwords_en = set(stopwords.words('english'))


def tokenize(document, word):
    tokenizer = nltk.RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(document)
    tokens = [
        token for token in tokens if token not in stopwords_en and token.isalpha()]
    tokens = [token for token in tokens if token != word]
    return set(tokens)

# %%
def extended_lesk(context, word):
    context = context.lower()
    word = word.lower()

    context_tokens = tokenize(context, word)

    # calculating the word sense disambiguation using simple LESK
    synsets = wordnet.synsets(word)
    # print(synsets)
    finWeights = [0] * len(synsets)
    N_t = len(synsets)
    weights= {}

    for context_token in context_tokens :
        weights[context_token] = 1
        for sense in synsets:
            if context_token in sense.definition():
                weights[context_token] += N_t
                continue

            for example in sense.examples():
                if context_token in example:
                    weights[context_token] += N_t
                    break

            for lemma in sense.lemma_names():
                if context_token in lemma:
                    weights[context_token] += N_t
                    break

    for ind,sense in enumerate(synsets):
        overlap = set()
        for example in sense.examples():
            for token in tokenize(example, word):
                overlap.add(token)

        for token in tokenize(sense.definition(), word):
            overlap.add(token)

        for token in sense.lemma_names():
            overlap.add(token)

        for token in context_tokens:
            if token in overlap:
                finWeights[ind] += np.log(weights[token] / N_t)
    if len(finWeights) == 0:
        return None
    max_weight = max(finWeights)
    index = finWeights.index(max_weight)
    return synsets[index]

# %% [markdown]
# ### Accuracy of Extended Lesk Algorithm

# %%
print(accuracy(extended_lesk, data), "%")
# Out:
# 51.71681020020132 %
